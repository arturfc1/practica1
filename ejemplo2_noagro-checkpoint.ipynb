# %%
conda install -c conda-forge/label/gcc7 missingno
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = 'noagro.csv'
df = pd.read_csv( path, encoding = 'latin', error_bad_lines = False)
df.head()
# Out:
#     folioviv  foliohog  numren  id_trabajo  tipoact  numesta totesta lugact  \
# 0  100013602         1       1           1        3        2
# 1  100013602         1       3           1        3        1              1
# 2  100013606         1       1           1        2        2
# 3  100027201         1       1           1        2        1              5
# 4  100027204         1       1           1        3        1              1
#
#    socios numsocio  ... ero3 ero4 ero5 ero6   ing_tri ero_tri ventas_tri  \
# 0       2           ...    0    0    0    0  12874.42     0.0   66393.44
# 1       2           ...    0    0    0    0    885.24     0.0     885.24
# 2       2           ...    0    0    0    0  34377.04     0.0   42786.88
# 3       2           ...    0    0    0    0   1253.03     0.0    5429.83
# 4       2           ...    0    0    0    0   1553.86     0.0    1553.86
#
#   auto_tri otros_tri gasto_tri
# 0     0.00       0.0  53519.01
# 1     0.00       0.0      0.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18984 entries, 0 to 18983
# Columns: 105 entries, folioviv to gasto_tri
# dtypes: float64(27), int64(28), object(50)
# memory usage: 15.2+ MB

# %%
#(filas,columnas)
df.shape
# Out:
# (18984, 105)

# %%
#numero de filas
df.shape[0]
# Out:
# 18984

# %%
#numero de columnas
df.shape[1]
# Out:
# 105

# %%
# nombre de las columnas
df.columns.values.tolist()
# Out:
# ['folioviv',
#  'foliohog',
#  'numren',
#  'id_trabajo',
#  'tipoact',
#  'numesta',
#  'totesta',
#  'lugact',
#  'socios',
#  'numsocio',
#  'phogar1',
#  'mismop',
#  'mes_2',
#  'mes_3',
#  'mes_4',
#  'mes_5',
#  'mes_6',
#  'phogar2',
#  'phogar3',
#  'phogar4',
#  'phogar5',
#  'phogar6',
#  'otro_pago',
#  'fpago_1',
#  'fpago_2',
#  'fpago_3',
#  'fpago_4',
#  'fpago_5',
#  'fpago_6',
#  'fpago_7',
#  'fpago_8',
#  'nofpago',
#  't_emp',
#  'h_emp',
#  'm_emp',
#  't_cpago',
#  'h_cpago',
#  'm_cpago',
#  't_ispago',
#  'h_ispago',
#  'm_ispago',
#  't_nispago',
#  'h_nispago',
#  'm_nispago',
#  'autocons',
#  'enproduc',
#  'novend',
#  'consinter',
#  'peract',
#  'mesact_1',
#  'mesact_2',
#  'mesact_3',
#  'mesact_4',
#  'mesact_5',
#  'mesact_6',
#  'mesact_7',
#  'mesact_8',
#  'mesact_9',
#  'mesact_10',
#  'mesact_11',
#  'mesact_12',
#  'reg_not',
#  'reg_cont',
#  'ventas1',
#  'ventas2',
#  'ventas3',
#  'ventas4',
#  'ventas5',
#  'ventas6',
#  'autocons1',
# ...

# %%
df.dtypes
# Out:
# folioviv        int64
# foliohog        int64
# numren          int64
# id_trabajo      int64
# tipoact         int64
#                ...
# ero_tri       float64
# ventas_tri    float64
# auto_tri      float64
# otros_tri     float64
# gasto_tri     float64
# Length: 105, dtype: object

# %%
#valores faltantes ?
df.isnull().any().any()
# Out:
# False

# %%
msno.matrix(df)

# %%
df.replace({'': np.nan}, inplace = True)

# %%
df.isnull().any().any()
# Out:
# False

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
#columnas con valores faltantes
df.columns[df.isnull().any()].tolist()
# Out:
# []

# %%
#resumen de estadisticas
df.describe()
# Out:
#            folioviv      foliohog        numren    id_trabajo       tipoact  \
# count  1.898400e+04  18984.000000  18984.000000  18984.000000  18984.000000
# mean   1.725755e+09      1.011536      1.687684      1.148283      2.119785
# std    9.037986e+08      0.119366      0.934264      0.355389      0.797312
# min    1.000136e+08      1.000000      1.000000      1.000000      1.000000
# 25%    1.000635e+09      1.000000      1.000000      1.000000      1.000000
# 50%    1.702960e+09      1.000000      1.000000      1.000000      2.000000
# 75%    2.500827e+09      1.000000      2.000000      1.000000      3.000000
# max    3.260799e+09      4.000000     12.000000      2.000000      3.000000
#
#             numesta        socios     otro_pago         t_emp      autocons  \
# count  18984.000000  18984.000000  18984.000000  18984.000000  18984.000000
# mean       1.303993      1.982880      1.955700      0.550674      1.474768
# ...

# %%
#seleccionamos filas con indices especificos
df.loc[[0]]
# Out:
#     folioviv  foliohog  numren  id_trabajo  tipoact  numesta totesta lugact  \
# 0  100013602         1       1           1        3        2
#
#    socios numsocio  ... ero3 ero4 ero5 ero6   ing_tri ero_tri ventas_tri  \
# 0       2           ...    0    0    0    0  12874.42     0.0   66393.44
#
#   auto_tri otros_tri gasto_tri
# 0      0.0       0.0  53519.01
#
# [1 rows x 105 columns]

# %%
#seleccionamos filas con indices especificos
df.loc[30:33]
# Out:
#      folioviv  foliohog  numren  id_trabajo  tipoact  numesta totesta lugact  \
# 30  100170502         1       1           2        3        1              1
# 31  100170503         1       1           1        1        2
# 32  100170506         1       2           1        2        1              1
# 33  100175305         1       2           1        2        2
#
#     socios numsocio  ... ero3 ero4 ero5 ero6   ing_tri ero_tri ventas_tri  \
# 30       2           ...    0    0    0    0  18073.36    0.00   29347.82
# 31       2           ...    0    0    0    0   7381.95    0.00   41331.52
# 32       2           ...    0    0    0    0   1711.95    0.00    7043.47
# 33       2           ...   50  110   50  550    611.41  396.19    4793.47
#
#    auto_tri otros_tri gasto_tri
# 30      0.0       0.0  11274.45
# 31      0.0       0.0  33949.56
# 32      0.0       0.0   5331.52
# 33      0.0       0.0   4578.26
#
# [4 rows x 105 columns]

# %%
#excluimos filas con indices especificos
df.drop([0,24,510], axis = 0).head()
# Out:
#     folioviv  foliohog  numren  id_trabajo  tipoact  numesta totesta lugact  \
# 1  100013602         1       3           1        3        1              1
# 2  100013606         1       1           1        2        2
# 3  100027201         1       1           1        2        1              5
# 4  100027204         1       1           1        3        1              1
# 5  100027205         1       1           1        2        2
#
#    socios numsocio  ... ero3 ero4 ero5 ero6   ing_tri ero_tri ventas_tri  \
# 1       2           ...    0    0    0    0    885.24     0.0     885.24
# 2       2           ...    0    0    0    0  34377.04     0.0   42786.88
# 3       2           ...    0    0    0    0   1253.03     0.0    5429.83
# 4       2           ...    0    0    0    0   1553.86     0.0    1553.86
# 5       2           ...    0    0    0    0  50345.30     0.0  147863.53
#
#   auto_tri otros_tri gasto_tri
# 1     0.00       0.0      0.00
# 2   885.24       0.0   9295.08
# ...

# %%
#excluimos ranfos especificos de lsa filas
df.drop(df.index[1:5], axis = 0).head(10)
# Out:
#      folioviv  foliohog  numren  id_trabajo  tipoact  numesta totesta lugact  \
# 0   100013602         1       1           1        3        2
# 5   100027205         1       1           1        2        2
# 6   100054303         1       2           1        1        1              3
# 7   100067401         1       3           1        3        1              2
# 8   100067401         1       3           2        1        1              2
# 9   100067403         1       1           1        3        1              2
# 10  100068904         1       2           1        2        1              3
# 11  100074002         1       2           1        1        2
# 12  100074004         1       2           1        3        1              1
# 13  100076402         1       2           1        3        2
#
#     socios numsocio  ... ero3 ero4 ero5 ero6   ing_tri ero_tri ventas_tri  \
# 0        2           ...    0    0    0    0  12874.42     0.0   66393.44
# ...

# %%
#subconjunto basado en desplazamiento desde arriba (abajo)
df[100:].head()
# Out:
#       folioviv  foliohog  numren  id_trabajo  tipoact  numesta totesta lugact  \
# 100  100534306         1       1           1        3        1              3
# 101  100569404         1       1           1        3        2
# 102  100569406         1       1           1        1        1              5
# 103  100578003         1       1           1        2        2
# 104  100590705         1       1           1        3        2
#
#      socios numsocio  ... ero3  ero4 ero5 ero6   ing_tri  ero_tri ventas_tri  \
# 100       2           ...    0     0    0    0  17417.93     0.00   42260.86
# 101       2           ...    0     0    0    0  15652.17     0.00   66032.60
# 102       2           ...    0     0    0    0  20934.78     0.00   20934.78
# 103       2           ...    0  1196    0    0   4948.04  1169.99   45684.78
# 104       2           ...    0     0    0    0  21393.44     0.00   26557.37
#
#     auto_tri otros_tri gasto_tri
# 100     0.00       0.0  24842.93
# ...

# %%
df.tail(-100)
# Out:
#          folioviv  foliohog  numren  id_trabajo  tipoact  numesta totesta  \
# 100     100534306         1       1           1        3        1
# 101     100569404         1       1           1        3        2
# 102     100569406         1       1           1        1        1
# 103     100578003         1       1           1        2        2
# 104     100590705         1       1           1        3        2
# ...           ...       ...     ...         ...      ...      ...     ...
# 18979  3260798022         1       1           1        1        1
# 18980  3260798413         1       1           1        1        2
# 18981  3260798415         1       1           1        3        1
# 18982  3260798808         1       1           1        1        1
# 18983  3260798810         1       1           1        3        1
#
#       lugact  socios numsocio  ... ero3  ero4 ero5 ero6   ing_tri  ero_tri  \
# 100        3       2           ...    0     0    0    0  17417.93     0.00
# ...

# %%
#obtener valores para el crimen
df.autocons.values
# Out:
# array([2, 2, 1, ..., 1, 1, 1], dtype=int64)

# %%
df['autocons'].values
# Out:
# array([2, 2, 1, ..., 1, 1, 1], dtype=int64)

# %%
df.autocons.unique()
# Out:
# array([2, 1], dtype=int64)

# %%
df.autocons.value_counts()
# Out:
# 1    9971
# 2    9013
# Name: autocons, dtype: int64

# %%
#obtener el numero de valores unicos
df.agg(['count', 'size','nunique'])
# Out:
#          folioviv  foliohog  numren  id_trabajo  tipoact  numesta  totesta  \
# count       18984     18984   18984       18984    18984    18984    18984
# size        18984     18984   18984       18984    18984    18984    18984
# nunique     16331         4      12           2        3        3        5
#
#          lugact  socios  numsocio  ...   ero3   ero4   ero5   ero6  ing_tri  \
# count     18984   18984     18984  ...  18984  18984  18984  18984    18984
# size      18984   18984     18984  ...  18984  18984  18984  18984    18984
# nunique      10       2        10  ...    784    743    704    725    11467
#
#          ero_tri  ventas_tri  auto_tri  otros_tri  gasto_tri
# count      18984       18984     18984      18984      18984
# size       18984       18984     18984      18984      18984
# nunique     2215        6458      3457        332      10830
#
# [3 rows x 105 columns]

# %%
df.groupby('autocons').agg(['count','size','nunique']).stack()
# Out:
#                   folioviv  foliohog  numren  id_trabajo  tipoact  numesta  \
# autocons
# 1        count        9971      9971    9971        9971     9971     9971
#          size         9971      9971    9971        9971     9971     9971
#          nunique      9083         4      10           2        3        3
# 2        count        9013      9013    9013        9013     9013     9013
#          size         9013      9013    9013        9013     9013     9013
#          nunique      8271         4      11           2        3        3
#
#                   totesta  lugact  socios  numsocio  ...  ero3  ero4  ero5  \
# autocons                                             ...
# 1        count       9971    9971    9971      9971  ...  9971  9971  9971
#          size        9971    9971    9971      9971  ...  9971  9971  9971
#          nunique        5      10       2         6  ...   569   522   512
# ...

# %%
df_sample = df.sample(frac = 0.05, random_state = 1)
df_sample.head()
# Out:
#          folioviv  foliohog  numren  id_trabajo  tipoact  numesta totesta  \
# 12323  2108123707         1       2           1        2        2
# 13685  2401049202         1       5           1        1        2
# 7930   1507902303         1       4           1        3        2
# 8900   1604854004         1       2           2        3        1
# 4080    860171524         1       2           1        3        1
#
#       lugact  socios numsocio  ... ero3 ero4 ero5 ero6   ing_tri ero_tri  \
# 12323              2           ...    0    0    0    0  36826.22     0.0
# 13685              2           ...    0    0    0    0   3478.17     0.0
# 7930               2           ...    0    0    0    0  83494.56     0.0
# 8900       6       2           ...    0    0    0    0   2357.60     0.0
# 4080       1       2           ...    0    0    0    0   2347.82     0.0
#
#       ventas_tri auto_tri otros_tri gasto_tri
# 12323   44999.99   526.22       0.0   8699.99
# ...

# %%
df.shape
# Out:
# (18984, 105)

# %%
df_sample.shape
# Out:
# (949, 105)

# %%
df_dropped = df.dropna(subset = ['numesta'])
df_dropped.head()
# Out:
#     folioviv  foliohog  numren  id_trabajo  tipoact  numesta totesta lugact  \
# 0  100013602         1       1           1        3        2
# 1  100013602         1       3           1        3        1              1
# 2  100013606         1       1           1        2        2
# 3  100027201         1       1           1        2        1              5
# 4  100027204         1       1           1        3        1              1
#
#    socios numsocio  ... ero3 ero4 ero5 ero6   ing_tri ero_tri ventas_tri  \
# 0       2           ...    0    0    0    0  12874.42     0.0   66393.44
# 1       2           ...    0    0    0    0    885.24     0.0     885.24
# 2       2           ...    0    0    0    0  34377.04     0.0   42786.88
# 3       2           ...    0    0    0    0   1253.03     0.0    5429.83
# 4       2           ...    0    0    0    0   1553.86     0.0    1553.86
#
#   auto_tri otros_tri gasto_tri
# 0     0.00       0.0  53519.01
# 1     0.00       0.0      0.00
# ...

# %%
df_dropped.shape
# Out:
# (18984, 105)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#     folioviv  foliohog  numren  id_trabajo  tipoact  numesta totesta lugact  \
# 0  100013602         1       1           1        3        2
# 1  100013602         1       3           1        3        1              1
# 2  100013606         1       1           1        2        2
# 3  100027201         1       1           1        2        1              5
# 4  100027204         1       1           1        3        1              1
#
#    socios numsocio  ... ero3 ero4 ero5 ero6   ing_tri ero_tri ventas_tri  \
# 0       2           ...    0    0    0    0  12874.42     0.0   66393.44
# 1       2           ...    0    0    0    0    885.24     0.0     885.24
# 2       2           ...    0    0    0    0  34377.04     0.0   42786.88
# 3       2           ...    0    0    0    0   1253.03     0.0    5429.83
# 4       2           ...    0    0    0    0   1553.86     0.0    1553.86
#
#   auto_tri otros_tri gasto_tri
# 0     0.00       0.0  53519.01
# 1     0.00       0.0      0.00
# ...

# %%
df_copy.shape
# Out:
# (18984, 105)

# %%
#Rellene los valores de conteo faltante con conteo medio
#Las funciones ffill () y bfill () copian los datos de la fila anterior (relleno hacia adelante) o el valor de la fila siguiente (relleno hacia atrás)
df_dropped['autocons'].dtype
# Out:
# dtype('int64')

# %%
df_dropped['autocons'].mean()
# Out:
# 1.4747682258744206

# %%
df_copy['autocons'].fillna(value=np.round(df['autocons'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          folioviv  foliohog  numren  id_trabajo  tipoact  numesta  totesta  \
# count       18984     18984   18984       18984    18984    18984    18984
# size        18984     18984   18984       18984    18984    18984    18984
# nunique     16331         4      12           2        3        3        5
#
#          lugact  socios  numsocio  ...   ero3   ero4   ero5   ero6  ing_tri  \
# count     18984   18984     18984  ...  18984  18984  18984  18984    18984
# size      18984   18984     18984  ...  18984  18984  18984  18984    18984
# nunique      10       2        10  ...    784    743    704    725    11467
#
#          ero_tri  ventas_tri  auto_tri  otros_tri  gasto_tri
# count      18984       18984     18984      18984      18984
# size       18984       18984     18984      18984      18984
# nunique     2215        6458      3457        332      10830
#
# [3 rows x 105 columns]

# %%
list(df['tipoact'].unique())
# Out:
# [3, 2, 1]

# %%
"""
3 actividades
2 actividades
1 actividades
"""
df['tipoact'].replace({3:"venta 3",
                       2:"venta 2",
                       1:"venta 1"}, inplace = True)

# %%
list(df['tipoact'].unique())
# Out:
# ['venta 3', 'venta 2', 'venta 1']

# %%
#creamos un diccionario

keys = list(df['tipoact'].unique())
vals = range(1,8)
act = dict(zip(keys, vals))
act
# Out:
# {'venta 3': 1, 'venta 2': 2, 'venta 1': 3}

# %%
df_copy['numesta'] = df['tipoact'].map(act)
df_copy.head()
# Out:
#     folioviv  foliohog  numren  id_trabajo  tipoact  numesta totesta lugact  \
# 0  100013602         1       1           1        3        1
# 1  100013602         1       3           1        3        1              1
# 2  100013606         1       1           1        2        2
# 3  100027201         1       1           1        2        2              5
# 4  100027204         1       1           1        3        1              1
#
#    socios numsocio  ... ero3 ero4 ero5 ero6   ing_tri ero_tri ventas_tri  \
# 0       2           ...    0    0    0    0  12874.42     0.0   66393.44
# 1       2           ...    0    0    0    0    885.24     0.0     885.24
# 2       2           ...    0    0    0    0  34377.04     0.0   42786.88
# 3       2           ...    0    0    0    0   1253.03     0.0    5429.83
# 4       2           ...    0    0    0    0   1553.86     0.0    1553.86
#
#   auto_tri otros_tri gasto_tri
# 0     0.00       0.0  53519.01
# 1     0.00       0.0      0.00
# ...

# %%
list(df_copy['ing_tri'].unique())
# Out:
# [12874.42,
#  885.24,
#  34377.04,
#  1253.03,
#  1553.86,
#  50345.3,
#  11885.86,
#  7141.3,
#  2768.96,
#  6793.53,
#  1408.69,
#  11035.76,
#  1036.95,
#  6539.67,
#  34.23,
#  4206.52,
#  3472.82,
#  13499.99,
#  1760.86,
#  1227.04,
#  8102.95,
#  8722.62,
#  51777.04,
#  5099.01,
#  18527.07,
#  12644.26,
#  0.0,
#  26779.89,
#  795.58,
#  855.97,
#  18073.36,
#  7381.95,
#  1711.95,
#  611.41,
#  16111.95,
#  49861.95,
#  3839.67,
#  33505.43,
#  18352.17,
#  14754.09,
#  3245.9,
#  28565.21,
#  3423.91,
#  3277.17,
#  18097.82,
#  215.4,
#  49.18,
#  15994.56,
#  2641.3,
#  1491.84,
#  14685.24,
#  295.08,
#  10573.77,
#  4384.56,
#  11519.02,
#  5178.68,
#  16434.78,
#  52923.91,
#  291.03,
#  1467.39,
#  30017.93,
#  16371.19,
#  5820.65,
#  7434.78,
#  4695.65,
#  2201.08,
#  6344.26,
#  3162.43,
#  32918.47,
#  8251.63,
#  27312.78,
#  35075.4,
#  17508.19,
#  15098.36,
#  4876.72,
#  21202.62,
#  2508.19,
#  8852.45,
#  9696.13,
#  5966.85,
#  7385.86,
#  3463.04,
# ...

# %%
df_copy['ing_tri'].mean()
# Out:
# 11387.150497260824

# %%
df_copy['ing_tri'][df_copy['ventas_tri'] == 6].mean()
# Out:
# nan

# %%
df_copy.groupby(["tipoact", "ing_tri","ventas_tri", "otros_tri"]).count()
# Out:
#                                         folioviv  foliohog  numren  \
# tipoact ing_tri   ventas_tri otros_tri
# 1       0.00      0.00       0.00             40        40      40
#                              19.56             1         1       1
#                              3442.62           1         1       1
#                   14.67      0.00              1         1       1
#                   34.23      0.00              1         1       1
# ...                                          ...       ...     ...
# 3       218887.82 293478.26  0.00              1         1       1
#         227934.78 254347.82  0.00              1         1       1
#         232258.69 352173.91  0.00              1         1       1
#         238671.19 267065.21  0.00              1         1       1
#         251902.17 316956.52  0.00              1         1       1
#
#                                         id_trabajo  numesta  totesta  lugact  \
# tipoact ing_tri   ventas_tri otros_tri
# ...

# %%
df_copy.groupby(["tipoact", "ing_tri"])[["ventas_tri", "otros_tri"]].count()
# Out:
#                    ventas_tri  otros_tri
# tipoact ing_tri
# 1       0.00              111        111
#         0.48                1          1
#         9.83                1          1
#         11.80               1          1
#         14.67               1          1
# ...                       ...        ...
# 3       218887.82           1          1
#         227934.78           1          1
#         232258.69           1          1
#         238671.19           1          1
#         251902.17           1          1
#
# [14125 rows x 2 columns]

# %%
df_copy.tipoact
# Out:
# 0        3
# 1        3
# 2        2
# 3        2
# 4        3
#         ..
# 18979    1
# 18980    1
# 18981    3
# 18982    1
# 18983    3
# Name: tipoact, Length: 18984, dtype: int64

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#          folioviv  foliohog  numren  id_trabajo  tipoact  numesta totesta  \
# 12323  2108123707         1       2           1  venta 2        2
# 13685  2401049202         1       5           1  venta 1        2
# 7930   1507902303         1       4           1  venta 3        2
# 8900   1604854004         1       2           2  venta 3        1
# 4080    860171524         1       2           1  venta 3        1
#
#       lugact  socios numsocio  ... ero3 ero4 ero5 ero6   ing_tri ero_tri  \
# 12323              2           ...    0    0    0    0  36826.22     0.0
# 13685              2           ...    0    0    0    0   3478.17     0.0
# 7930               2           ...    0    0    0    0  83494.56     0.0
# 8900       6       2           ...    0    0    0    0   2357.60     0.0
# 4080       1       2           ...    0    0    0    0   2347.82     0.0
#
#       ventas_tri auto_tri otros_tri gasto_tri
# 12323   44999.99   526.22       0.0   8699.99
# ...

# %%
# variante 1: agregacion multiple o un solo atributo
df_sample.groupby(["tipoact", "ing_tri"])[["ventas_tri", "otros_tri"]].agg([np.sum, np.mean,
                                                              np.count_nonzero])
# Out:
#                   ventas_tri                              otros_tri  \
#                          sum           mean count_nonzero       sum
# tipoact ing_tri
# venta 1 0.00        23970.70    3995.116667           5.0    158.96
#         25.43        4319.99    4319.990000           1.0      0.00
#         29.34          39.13      39.130000           1.0      0.00
#         73.36          97.82      97.820000           1.0      0.00
#         97.82          97.82      97.820000           1.0      0.00
# ...                      ...            ...           ...       ...
# venta 3 97918.03   135737.70  135737.700000           1.0      0.00
#         122401.46  199565.21  199565.210000           1.0      0.00
#         125408.85  424157.21  424157.210000           1.0      0.00
#         128196.19  305706.52  305706.520000           1.0      0.00
#         163247.28  192864.13  192864.130000           1.0      0.00
#
#
#                         mean count_nonzero
# tipoact ing_tri
# ...

# %%
# variante 2: diferentes funciones de agracion para un atributo

df_sample.groupby(["tipoact", "ing_tri"]).agg({'numesta':np.mean,'otros_tri':np.max})
# Out:
#                     numesta  otros_tri
# tipoact ing_tri
# venta 1 0.00       1.166667     158.96
#         25.43      2.000000       0.00
#         29.34      1.000000       0.00
#         73.36      1.000000       0.00
#         97.82      1.000000       0.00
# ...                     ...        ...
# venta 3 97918.03   1.000000       0.00
#         122401.46  2.000000       0.00
#         125408.85  2.000000       0.00
#         128196.19  2.000000       0.00
#         163247.28  1.000000       0.00
#
# [902 rows x 2 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
#The equivalent of this command within the object-oriented interface is fig.add_axes()

fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
# The lowest level of these is plt.subplot(), which creates a single subplot within a grid
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
# plt.subplots_adjust can be used to adjust the spacing between these plots
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
# axes are in a two-dimensional array, indexed by [row, col]
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
fig

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
#figure.savefig('.../.jpeg')

df_sample['numesta'] = df_sample['numesta'].astype('int64')

df_sample.plot(kind='scatter',x='numesta',y='ing_tri')

# %%
plt.hist(df_sample['tipoact'])
plt.xlabel('tipoact')
plt.ylabel('Frequency')
plt.title('Frequency of tipoact')
# Out:
# Text(0.5, 1.0, 'Frequency of tipoact')

# %%
plt.hist(df_sample['numesta'])
plt.xlabel('numesta')
plt.ylabel('Frequency')
plt.title('Frequency of numesta')
# Out:
# Text(0.5, 1.0, 'Frequency of numesta')

# %%
#plt.boxplot(df_sample['ventas'])
plt.boxplot(df_sample['numesta'], showmeans=True, meanline=True)
plt.ylabel('numesta count')
plt.title('Box Plot of numesta count')
# Out:
# Text(0.5, 1.0, 'Box Plot of numesta count')
