# %%
conda install -c conda-forge/label/gcc7 missingno
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
path = 'gastoshogar.csv'
df = pd.read_csv(path, encoding = 'latin', error_bad_lines = False)
df.head()
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (13,14,16,20,21,22,23,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     folioviv  foliohog clave tipo_gasto  mes_dia  forma_pag1  forma_pag2  \
# 0  100013601         1  C002         G1        0           1           0
# 1  100013601         1  C004         G1        0           1           0
# 2  100013601         1  C005         G1        0           1           0
# 3  100013601         1  D001         G1        0           1           0
# 4  100013601         1  F007         G1        0           1           0
#
#    forma_pag3  lugar_comp  orga_inst  ...  inmujer  inst_1  inst_2 num_meses  \
# 0           0           6          0  ...
# 1           0          10          0  ...
# 2           0          10          0  ...
# 3           0           6          0  ...       -1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4405250 entries, 0 to 4405249
# Data columns (total 27 columns):
# folioviv      int64
# foliohog      int64
# clave         object
# tipo_gasto    object
# mes_dia       int64
# forma_pag1    int64
# forma_pag2    int64
# forma_pag3    int64
# lugar_comp    int64
# orga_inst     int64
# frecuencia    int64
# fecha_adqu    int64
# fecha_pago    int64
# cantidad      object
# gasto         object
# pago_mp       object
# costo         object
# inmujer       object
# inst_1        object
# inst_2        object
# num_meses     object
# num_pagos     object
# ultim_pago    object
# gasto_tri     object
# gasto_nm      object
# gas_nm_tri    object
# imujer_tri    object
# dtypes: int64(11), object(16)
# memory usage: 907.5+ MB

# %%
df.shape
# Out:
# (4405250, 27)

# %%
df.shape[0]
# Out:
# 4405250

# %%
df.shape[1]
# Out:
# 27

# %%
df.columns.values.tolist()
# Out:
# ['folioviv',
#  'foliohog',
#  'clave',
#  'tipo_gasto',
#  'mes_dia',
#  'forma_pag1',
#  'forma_pag2',
#  'forma_pag3',
#  'lugar_comp',
#  'orga_inst',
#  'frecuencia',
#  'fecha_adqu',
#  'fecha_pago',
#  'cantidad',
#  'gasto',
#  'pago_mp',
#  'costo',
#  'inmujer',
#  'inst_1',
#  'inst_2',
#  'num_meses',
#  'num_pagos',
#  'ultim_pago',
#  'gasto_tri',
#  'gasto_nm',
#  'gas_nm_tri',
#  'imujer_tri']

# %%
df.dtypes
# Out:
# folioviv       int64
# foliohog       int64
# clave         object
# tipo_gasto    object
# mes_dia        int64
# forma_pag1     int64
# forma_pag2     int64
# forma_pag3     int64
# lugar_comp     int64
# orga_inst      int64
# frecuencia     int64
# fecha_adqu     int64
# fecha_pago     int64
# cantidad      object
# gasto         object
# pago_mp       object
# costo         object
# inmujer       object
# inst_1        object
# inst_2        object
# num_meses     object
# num_pagos     object
# ultim_pago    object
# gasto_tri     object
# gasto_nm      object
# gas_nm_tri    object
# imujer_tri    object
# dtype: object

# %%
df.isnull().any().any()
# Out:
# False

# %%
msno.matrix(df)

# %%
df.replace({'':np.nan}, inplace = True)

# %%
df.isnull().any().any()
# Out:
# False

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# []

# %%
df.describe()
# Out:
#            folioviv      foliohog       mes_dia    forma_pag1    forma_pag2  \
# count  4.405250e+06  4.405250e+06  4.405250e+06  4.405250e+06  4.405250e+06
# mean   1.637799e+09  1.018017e+00  4.819009e+02  1.002952e+00  5.968106e-03
# std    9.312381e+08  1.525011e-01  4.867367e+02  8.003691e-01  2.065683e-01
# min    1.000136e+08  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    8.068047e+08  1.000000e+00  0.000000e+00  1.000000e+00  0.000000e+00
# 50%    1.603920e+09  1.000000e+00  0.000000e+00  1.000000e+00  0.000000e+00
# 75%    2.460361e+09  1.000000e+00  9.300000e+02  1.000000e+00  0.000000e+00
# max    3.260799e+09  5.000000e+00  1.114000e+03  1.000000e+01  1.000000e+01
#
#          forma_pag3    lugar_comp     orga_inst    frecuencia    fecha_adqu  \
# count  4.405250e+06  4.405250e+06  4.405250e+06  4.405250e+06  4.405250e+06
# mean   1.080529e-04  4.308600e+00  3.950536e-02  2.202345e-01  8.109490e+00
# ...

# %%
df.loc[[0]]
# Out:
#     folioviv  foliohog clave tipo_gasto  mes_dia  forma_pag1  forma_pag2  \
# 0  100013601         1  C002         G1        0           1           0
#
#    forma_pag3  lugar_comp  orga_inst  ...  inmujer  inst_1  inst_2 num_meses  \
# 0           0           6          0  ...
#
#   num_pagos ultim_pago gasto_tri gasto_nm gas_nm_tri imujer_tri
# 0                             90
#
# [1 rows x 27 columns]

# %%
df.loc [30:33]
# Out:
#      folioviv  foliohog clave tipo_gasto  mes_dia  forma_pag1  forma_pag2  \
# 30  100013602         1  H102         G1        0           1           0
# 31  100013602         1  H123         G1        0           1           0
# 32  100013602         1  H127         G1        0           1           0
# 33  100013602         1  H134         G1        0           1           0
#
#     forma_pag3  lugar_comp  orga_inst  ...  inmujer  inst_1  inst_2 num_meses  \
# 30           0           5          0  ...      180
# 31           0          17          0  ...
# 32           0           5          0  ...
# 33           0           5          0  ...      120
#
#    num_pagos ultim_pago gasto_tri gasto_nm gas_nm_tri imujer_tri
# 30                         176.08                         176.08
# 31                          68.47
# 32                          97.82
# 33                         117.39                         117.39
#
# [4 rows x 27 columns]

# %%
df.drop([0,24,51], axis=0).head()
# Out:
#     folioviv  foliohog clave tipo_gasto  mes_dia  forma_pag1  forma_pag2  \
# 1  100013601         1  C004         G1        0           1           0
# 2  100013601         1  C005         G1        0           1           0
# 3  100013601         1  D001         G1        0           1           0
# 4  100013601         1  F007         G1        0           1           0
# 5  100013602         1  C001         G1        0           5           0
#
#    forma_pag3  lugar_comp  orga_inst  ...  inmujer  inst_1  inst_2 num_meses  \
# 1           0          10          0  ...
# 2           0          10          0  ...
# 3           0           6          0  ...       -1
# 4           0           0          0  ...
# 5           0           6          0  ...
#
#   num_pagos ultim_pago gasto_tri gasto_nm gas_nm_tri imujer_tri
# 1                            252
# 2                            180
# 3                             99                             -1
# ...

# %%
df.drop(df.index[1:5], axis=0).head(10)
# Out:
#      folioviv  foliohog clave tipo_gasto  mes_dia  forma_pag1  forma_pag2  \
# 0   100013601         1  C002         G1        0           1           0
# 5   100013602         1  C001         G1        0           5           0
# 6   100013602         1  C003         G1        0           1           0
# 7   100013602         1  C004         G1        0           5           0
# 8   100013602         1  C006         G1        0           5           0
# 9   100013602         1  C013         G1        0           1           0
# 10  100013602         1  D001         G1        0           5           0
# 11  100013602         1  D003         G1        0           5           0
# 12  100013602         1  D005         G1        0           1           0
# 13  100013602         1  D006         G1        0           1           0
#
#     forma_pag3  lugar_comp  orga_inst  ...  inmujer  inst_1  inst_2 num_meses  \
# 0            0           6          0  ...
# ...

# %%
df[100:].head() #df.tail(-100)
# Out:
#       folioviv  foliohog clave tipo_gasto  mes_dia  forma_pag1  forma_pag2  \
# 100  100026701         1  C006         G1        0           1           0
# 101  100026701         1  C007         G1        0           1           0
# 102  100026701         1  C011         G1        0           1           0
# 103  100026701         1  C020         G1        0           1           0
# 104  100026701         1  D001         G1        0           1           0
#
#      forma_pag3  lugar_comp  orga_inst  ...  inmujer  inst_1  inst_2  \
# 100           0           6          0  ...
# 101           0           6          0  ...
# 102           0           6          0  ...
# 103           0          17          0  ...
# 104           0           6          0  ...       -1
#
#     num_meses num_pagos ultim_pago gasto_tri gasto_nm gas_nm_tri imujer_tri
# 100                                       90
# 101                                      900
# ...

# %%
df.gasto.values
# Out:
# array(['30', '84', '60', ..., ' ', '1000', ' '], dtype=object)

# %%
df['gasto'].values
# Out:
# array(['30', '84', '60', ..., ' ', '1000', ' '], dtype=object)

# %%
df.gasto.unique()
# Out:
# array(['30', '84', '60', ..., '9045', '3402', '9700'], dtype=object)

# %%
df.gasto.value_counts()
# Out:
#           379825
# 10        190755
# 20        171112
# 15        157478
# 30        132666
#            ...
# 60.76          1
# 61.26          1
# 183.19         1
# 58000          1
# 48.26          1
# Name: gasto, Length: 14302, dtype: int64

# %%
df.agg(['count','size', 'nunique'])
# Out:
#          folioviv  foliohog    clave  tipo_gasto  mes_dia  forma_pag1  \
# count     4405250   4405250  4405250     4405250  4405250     4405250
# size      4405250   4405250  4405250     4405250  4405250     4405250
# nunique     73405         5      756           6       64          11
#
#          forma_pag2  forma_pag3  lugar_comp  orga_inst  ...  inmujer   inst_1  \
# count       4405250     4405250     4405250    4405250  ...  4405250  4405250
# size        4405250     4405250     4405250    4405250  ...  4405250  4405250
# nunique          10           5          19         10  ...     1860       14
#
#           inst_2  num_meses  num_pagos  ultim_pago  gasto_tri  gasto_nm  \
# count    4405250    4405250    4405250     4405250    4405250   4405250
# size     4405250    4405250    4405250     4405250    4405250   4405250
# nunique       11         60         47         193      24207      2513
#
#          gas_nm_tri  imujer_tri
# count       4405250     4405250
# ...

# %%
df.groupby('gasto').agg(['count','size','nunique']).stack()
# Out:
#                folioviv  foliohog  clave  tipo_gasto  mes_dia  forma_pag1  \
# gasto
# 0.5   count          41        41     41          41       41          41
#       size           41        41     41          41       41          41
#       nunique        35         2     14           1       28           2
# 0.53  count           1         1      1           1        1           1
#       size            1         1      1           1        1           1
# ...                 ...       ...    ...         ...      ...         ...
# 998   size            5         5      5           5        5           5
#       nunique         5         1      5           1        1           2
# 999   count           3         3      3           3        3           3
#       size            3         3      3           3        3           3
#       nunique         3         1      3           1        1           1
#
# ...

# %%
df.groupby('gasto').agg(['count', 'size','nunique'])
# Out:
#       folioviv              foliohog              clave               \
#          count size nunique    count size nunique count size nunique
# gasto
# 0.5         41   41      35       41   41       2    41   41      14
# 0.53         1    1       1        1    1       1     1    1       1
# 0.58         1    1       1        1    1       1     1    1       1
# 0.6          1    1       1        1    1       1     1    1       1
# 0.62         1    1       1        1    1       1     1    1       1
# ...        ...  ...     ...      ...  ...     ...   ...  ...     ...
# 996          6    6       6        6    6       1     6    6       5
# 9960         1    1       1        1    1       1     1    1       1
# 99600        1    1       1        1    1       1     1    1       1
# 998          5    5       5        5    5       1     5    5       5
# 999          3    3       3        3    3       1     3    3       3
#
# ...

# %%
df_sample = df.sample(frac=0.5, random_state=1)
df_sample.head()
# Out:
#            folioviv  foliohog clave tipo_gasto  mes_dia  forma_pag1  \
# 236300    460133714         1  C008         G1        0           1
# 2509218   660026717         1  A031         G1     1010           1
# 916815   1661282618         1  J026         G1        0           1
# 1429049  2600850405         1  D016         G1        0           1
# 4047426  3160327214         1  A220         G1      820           1
#
#          forma_pag2  forma_pag3  lugar_comp  orga_inst  ...  inmujer  inst_1  \
# 236300            0           0          15          0  ...
# 2509218           0           0           5          0  ...
# 916815            0           0           5          0  ...       60      01
# 1429049           0           0           6          0  ...        0
# 4047426           0           0           4          0  ...
#
#          inst_2 num_meses num_pagos ultim_pago gasto_tri gasto_nm gas_nm_tri  \
# 236300                                               225
# ...

# %%
df.shape
# Out:
# (4405250, 27)

# %%
df_sample.shape
# Out:
# (2202625, 27)

# %%
df_dropped = df.dropna(subset= ['gasto_tri'])
df_dropped.head()
# Out:
#     folioviv  foliohog clave tipo_gasto  mes_dia  forma_pag1  forma_pag2  \
# 0  100013601         1  C002         G1        0           1           0
# 1  100013601         1  C004         G1        0           1           0
# 2  100013601         1  C005         G1        0           1           0
# 3  100013601         1  D001         G1        0           1           0
# 4  100013601         1  F007         G1        0           1           0
#
#    forma_pag3  lugar_comp  orga_inst  ...  inmujer  inst_1  inst_2 num_meses  \
# 0           0           6          0  ...
# 1           0          10          0  ...
# 2           0          10          0  ...
# 3           0           6          0  ...       -1
# 4           0           0          0  ...
#
#   num_pagos ultim_pago gasto_tri gasto_nm gas_nm_tri imujer_tri
# 0                             90
# 1                            252
# 2                            180
# ...

# %%
df_dropped.shape
# Out:
# (4405250, 27)

# %%
df_copy= df.copy()
df_copy.head()
# Out:
#     folioviv  foliohog clave tipo_gasto  mes_dia  forma_pag1  forma_pag2  \
# 0  100013601         1  C002         G1        0           1           0
# 1  100013601         1  C004         G1        0           1           0
# 2  100013601         1  C005         G1        0           1           0
# 3  100013601         1  D001         G1        0           1           0
# 4  100013601         1  F007         G1        0           1           0
#
#    forma_pag3  lugar_comp  orga_inst  ...  inmujer  inst_1  inst_2 num_meses  \
# 0           0           6          0  ...
# 1           0          10          0  ...
# 2           0          10          0  ...
# 3           0           6          0  ...       -1
# 4           0           0          0  ...
#
#   num_pagos ultim_pago gasto_tri gasto_nm gas_nm_tri imujer_tri
# 0                             90
# 1                            252
# 2                            180
# ...

# %%
df_copy.shape
# Out:
# (4405250, 27)

# %%
df_dropped['lugar_comp'].dtype
# Out:
# dtype('int64')

# %%
df_dropped['lugar_comp'].mean()
# Out:
# 4.308600419953464

# %%
df_copy['lugar_comp'].fillna(value=np.round(df['lugar_comp'].mean(),decimals=0),inplace = True)

# %%
df_copy.agg(['count','size', 'nunique'])
# Out:
#          folioviv  foliohog    clave  tipo_gasto  mes_dia  forma_pag1  \
# count     4405250   4405250  4405250     4405250  4405250     4405250
# size      4405250   4405250  4405250     4405250  4405250     4405250
# nunique     73405         5      756           6       64          11
#
#          forma_pag2  forma_pag3  lugar_comp  orga_inst  ...  inmujer   inst_1  \
# count       4405250     4405250     4405250    4405250  ...  4405250  4405250
# size        4405250     4405250     4405250    4405250  ...  4405250  4405250
# nunique          10           5          19         10  ...     1860       14
#
#           inst_2  num_meses  num_pagos  ultim_pago  gasto_tri  gasto_nm  \
# count    4405250    4405250    4405250     4405250    4405250   4405250
# size     4405250    4405250    4405250     4405250    4405250   4405250
# nunique       11         60         47         193      24207      2513
#
#          gas_nm_tri  imujer_tri
# count       4405250     4405250
# ...

# %%
list(df['tipo_gasto'].unique())
# Out:
# ['G1', 'G3', 'G5', 'G6', 'G2', 'G7']

# %%
""""
G1 Medicinas
G3 Transporte
G5 Escuela
G6 Alimentos
G2 Vestido y calzado
G7 Vivienda y servicios de conservacion
"""
df['tipo_gasto'].replace ({
    1:"medicinas",
    3:"transporte",
    5:"escuela",
    6:"alimentos",
    2:"vestido",
    7:"vivienda"}, inplace=True)

# %%
list(df['tipo_gasto'].unique())
# Out:
# ['G1', 'G3', 'G5', 'G6', 'G2', 'G7']

# %%
keys = list(df['tipo_gasto'].unique())
vals = range (1,8)
act = dict (zip(keys, vals))
act
# Out:
# {'G1': 1, 'G3': 2, 'G5': 3, 'G6': 4, 'G2': 5, 'G7': 6}

# %%
df_copy['tipo_gasto'] = df['tipo_gasto'].map(act)
df_copy.head()
# Out:
#     folioviv  foliohog clave  tipo_gasto  mes_dia  forma_pag1  forma_pag2  \
# 0  100013601         1  C002           1        0           1           0
# 1  100013601         1  C004           1        0           1           0
# 2  100013601         1  C005           1        0           1           0
# 3  100013601         1  D001           1        0           1           0
# 4  100013601         1  F007           1        0           1           0
#
#    forma_pag3  lugar_comp  orga_inst  ...  inmujer  inst_1  inst_2 num_meses  \
# 0           0           6          0  ...
# 1           0          10          0  ...
# 2           0          10          0  ...
# 3           0           6          0  ...       -1
# 4           0           0          0  ...
#
#   num_pagos ultim_pago gasto_tri gasto_nm gas_nm_tri imujer_tri
# 0                             90
# 1                            252
# 2                            180
# ...

# %%
list(df_copy['tipo_gasto'].unique())
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
df_copy['']
